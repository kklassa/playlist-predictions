# %%
import pandas as pd
import pickle
import requests

# %% [markdown]
# #### Data Preperation

# %%
data = pd.read_csv('../data/prepared_data_v3.csv')
no_weeks = data['week_number'].max()
for week in range(no_weeks):
    data.loc[data['week_number'] == week, 'next_week_plays'] = data.loc[data['week_number'] == week+1, 'track_plays'].values

data['next_week_plays'] = data['next_week_plays'].fillna(0).astype(int)
data = data.drop(data[data['week_number'] == no_weeks].index)

# %%
def load_week_data(data: pd.DataFrame, week_number: int) -> pd.DataFrame:
    return data[data['week_number'] == week_number].copy()

# %%
week_data = load_week_data(data, 1)
next_week_data = load_week_data(data, 2)

# %%
next_week_top_tracks  = next_week_data.sort_values(by='track_plays', ascending=False).head(50)

# %%
next_week_top_tracks[['track_plays', 'name_track', 'name_artist']]
# Out:
#        track_plays                                name_track  \
# 54223           42                                  Memories
# 58509           40                              The Business
# 55568           37                                   Snowman
# 64382           35                                   Whoopty
# 58639           35                                The Nights
# 63061           34                        you broke me first
# 62828           34                                   Falling
# 64327           34                               WITHOUT YOU
# 55997           32                                 All of Me
# 62826           31                                    Golden
# 64384           31                                Goosebumps
# 63333           31                              Lucid Dreams
# 62047           31                       everything i wanted
# 64386           31                           Coração Na Cama
# 62046           30                                   bad guy
# 61100           30                                Devil Eyes
# 56130           30  Why'd You Only Call Me When You're High?
# 60741           30                                     34+35
# 55217           30                                  PROBLEMA
# 57781           30                                   Hold On
# 63818           30                                   Heather
# 63880           30                                   Ride It
# 59287           29                                Follow You
# 59844           29                               Train Wreck
# 58693           29                                 Afterglow
# 57600           29                               What’s Next
# 61297           29                           hot girl bummer
# 63977           29                                   deja vu
# 63976           29                           drivers license
# 59845           28                      Say You Won't Let Go
# 63965           28                                   RAPSTAR
# 63334           28                    All Girls Are The Same
# 59279           28                                  Believer
# 58524           28                                 La Tóxica
# 55731           28  Cupid's Chokehold / Breakfast in America
# 60210           28                                  Dynamite
# 62787           28                            Jocelyn Flores
# 56768           28                                   Hayloft
# 64694           27                             Tapão Na Raba
# 59365           27                The Less I Know The Better
# 59457           27                              In Your Eyes
# 63881           27                                      Dior
# 57978           27                              Stressed Out
# 61420           27                       HIGHEST IN THE ROOM
# 62166           27                                TE MUDASTE
# 61408           26                                SICKO MODE
# 63819           26                                    Maniac
# 63483           26                         Someone You Loved
# 62048           26                     when the party's over
# 59456           26                           Blinding Lights
#
#              name_artist
# 54223           Maroon 5
# 58509             Tiësto
# 55568                Sia
# 64382                 CJ
# 58639             Avicii
# 63061         Tate McRae
# 62828       Harry Styles
# 64327      The Kid LAROI
# 55997        John Legend
# 62826       Harry Styles
# 64384               HVME
# 63333         Juice WRLD
# 62047      Billie Eilish
# 64386   Hugo & Guilherme
# 62046      Billie Eilish
# 61100    Hippie Sabotage
# 56130     Arctic Monkeys
# 60741      Ariana Grande
# 55217       Daddy Yankee
# 57781      Justin Bieber
# 63818         Conan Gray
# 63880             Regard
# 59287    Imagine Dragons
# 59844       James Arthur
# 58693         Ed Sheeran
# 57600              Drake
# 61297          blackbear
# 63977     Olivia Rodrigo
# 63976     Olivia Rodrigo
# 59845       James Arthur
# 63965             Polo G
# 63334         Juice WRLD
# 59279    Imagine Dragons
# 58524            Farruko
# 55731   Gym Class Heroes
# 60210                BTS
# 62787       XXXTENTACION
# 56768      Mother Mother
# 64694    Raí Saia Rodada
# 59365        Tame Impala
# 59457         The Weeknd
# 63881          Pop Smoke
# 57978  Twenty One Pilots
# 61420       Travis Scott
# 62166          Bad Bunny
# 61408       Travis Scott
# 63819         Conan Gray
# 63483      Lewis Capaldi
# 62048      Billie Eilish
# 59456         The Weeknd

# %%
week_data.drop(columns=['week_number', 'name_track', 'name_artist', 'release_date', 'genres'], inplace=True)

# %%
week_data_input = week_data.drop('next_week_plays', axis=1).values.tolist()

# %% [markdown]
# #### Predictions

# %%
torch_res = requests.post('http://localhost:8080/torch-model/top-playlist', json=week_data_input)
xgb_res = requests.post('http://localhost:8080/xgb-model/top-playlist', json=week_data_input)

# %%
torch_predicted_top_tracks = next_week_data[next_week_data['id_track'].isin(torch_res.json())]

# %%
torch_predicted_top_tracks[['track_plays', 'name_track', 'name_artist']]
# Out:
#        track_plays                                name_track  \
# 53152           23                                    Yellow
# 55568           37                                   Snowman
# 55731           28  Cupid's Chokehold / Breakfast in America
# 56130           30  Why'd You Only Call Me When You're High?
# 57779           23                                   Hold On
# 57780           25                                    Anyone
# 58509           40                              The Business
# 58684           24                              Shape of You
# 58693           29                                 Afterglow
# 59287           29                                Follow You
# 59365           27                The Less I Know The Better
# 59435           23                                 The Hills
# 59455           23                           Save Your Tears
# 59726           22                           Sweater Weather
# 59732           20                              Daddy Issues
# 59844           29                               Train Wreck
# 59845           28                      Say You Won't Let Go
# 60735           15                                   7 rings
# 60741           30                                     34+35
# 61100           30                                Devil Eyes
# 61154           26                                   Streets
# 61403           18                                goosebumps
# 61599           23                           Don't Start Now
# 61718           24                                 telepatía
# 62059           26                            Therefore I Am
# 62166           27                                TE MUDASTE
# 62825           20                          Watermelon Sugar
# 62826           31                                    Golden
# 62827           21                                 Adore You
# 62828           34                                   Falling
# 62863           21                             Star Shopping
# 63061           34                        you broke me first
# 63333           31                              Lucid Dreams
# 63347           23                                   Robbery
# 63483           26                         Someone You Loved
# 63484           24                             Before You Go
# 63550           22                                   ROXANNE
# 63818           30                                   Heather
# 63819           26                                    Maniac
# 63880           30                                   Ride It
# 63881           27                                      Dior
# 63962           23                             Martin & Gina
# 63965           28                                   RAPSTAR
# 63977           29                                   deja vu
# 63990           19                                   HOLIDAY
# 64369           24                                   BICHOTA
# 64382           35                                   Whoopty
# 64385           17                       Put Your Records On
# 64679           23                    Astronaut In The Ocean
# 64694           27                             Tapão Na Raba
#
#              name_artist
# 53152           Coldplay
# 55568                Sia
# 55731   Gym Class Heroes
# 56130     Arctic Monkeys
# 57779      Justin Bieber
# 57780      Justin Bieber
# 58509             Tiësto
# 58684         Ed Sheeran
# 58693         Ed Sheeran
# 59287    Imagine Dragons
# 59365        Tame Impala
# 59435         The Weeknd
# 59455         The Weeknd
# 59726  The Neighbourhood
# 59732  The Neighbourhood
# 59844       James Arthur
# 59845       James Arthur
# 60735      Ariana Grande
# 60741      Ariana Grande
# 61100    Hippie Sabotage
# 61154           Doja Cat
# 61403       Travis Scott
# 61599           Dua Lipa
# 61718         Kali Uchis
# 62059      Billie Eilish
# 62166          Bad Bunny
# 62825       Harry Styles
# 62826       Harry Styles
# 62827       Harry Styles
# 62828       Harry Styles
# 62863           Lil Peep
# 63061         Tate McRae
# 63333         Juice WRLD
# 63347         Juice WRLD
# 63483      Lewis Capaldi
# 63484      Lewis Capaldi
# 63550     Arizona Zervas
# 63818         Conan Gray
# 63819         Conan Gray
# 63880             Regard
# 63881          Pop Smoke
# 63962             Polo G
# 63965             Polo G
# 63977     Olivia Rodrigo
# 63990          Lil Nas X
# 64369            KAROL G
# 64382                 CJ
# 64385        Ritt Momney
# 64679        Masked Wolf
# 64694    Raí Saia Rodada

# %%
torch_matching_tracks = next_week_top_tracks[next_week_top_tracks['id_track'].isin(torch_res.json())]

# %%
len(torch_matching_tracks)
# Out:
# 25

# %%
xgb_predicted_top_tracks = next_week_top_tracks[next_week_top_tracks['id_track'].isin(xgb_res.json())]

# %%
xgb_predicted_top_tracks[['track_plays', 'name_track', 'name_artist']]
# Out:
#        track_plays                                name_track  \
# 54223           42                                  Memories
# 55568           37                                   Snowman
# 64382           35                                   Whoopty
# 58639           35                                The Nights
# 63061           34                        you broke me first
# 62828           34                                   Falling
# 55997           32                                 All of Me
# 64384           31                                Goosebumps
# 63333           31                              Lucid Dreams
# 62047           31                       everything i wanted
# 64386           31                           Coração Na Cama
# 62046           30                                   bad guy
# 56130           30  Why'd You Only Call Me When You're High?
# 57781           30                                   Hold On
# 63818           30                                   Heather
# 63880           30                                   Ride It
# 59287           29                                Follow You
# 59844           29                               Train Wreck
# 61297           29                           hot girl bummer
# 63977           29                                   deja vu
# 59845           28                      Say You Won't Let Go
# 63965           28                                   RAPSTAR
# 59279           28                                  Believer
# 58524           28                                 La Tóxica
# 55731           28  Cupid's Chokehold / Breakfast in America
# 56768           28                                   Hayloft
# 59457           27                              In Your Eyes
# 63881           27                                      Dior
# 57978           27                              Stressed Out
# 62166           27                                TE MUDASTE
# 63483           26                         Someone You Loved
# 62048           26                     when the party's over
#
#              name_artist
# 54223           Maroon 5
# 55568                Sia
# 64382                 CJ
# 58639             Avicii
# 63061         Tate McRae
# 62828       Harry Styles
# 55997        John Legend
# 64384               HVME
# 63333         Juice WRLD
# 62047      Billie Eilish
# 64386   Hugo & Guilherme
# 62046      Billie Eilish
# 56130     Arctic Monkeys
# 57781      Justin Bieber
# 63818         Conan Gray
# 63880             Regard
# 59287    Imagine Dragons
# 59844       James Arthur
# 61297          blackbear
# 63977     Olivia Rodrigo
# 59845       James Arthur
# 63965             Polo G
# 59279    Imagine Dragons
# 58524            Farruko
# 55731   Gym Class Heroes
# 56768      Mother Mother
# 59457         The Weeknd
# 63881          Pop Smoke
# 57978  Twenty One Pilots
# 62166          Bad Bunny
# 63483      Lewis Capaldi
# 62048      Billie Eilish

# %%
xgb_matching_tracks = next_week_top_tracks[next_week_top_tracks['id_track'].isin(xgb_res.json())]

# %%
len(xgb_matching_tracks)
# Out:
# 32

# %% [markdown]
# #### A/B Testing

# %%
import numpy as np
from scipy import stats

# %%
weeks_to_test = np.random.choice(range(51), size=20, replace=False)

# %%
def get_matches_for_week(week_number):
    week_data = load_week_data(data, week_number)
    next_week_data = load_week_data(data, week_number+1)

    next_week_top_tracks  = next_week_data.sort_values(by='track_plays', ascending=False).head(50)

    week_data.drop(columns=['week_number', 'name_track', 'name_artist', 'release_date', 'genres'], inplace=True)

    week_data_input = week_data.drop('next_week_plays', axis=1).values.tolist()

    torch_res = requests.post('http://localhost:8080/torch-model/top-playlist', json=week_data_input)
    xgb_res = requests.post('http://localhost:8080/xgb-model/top-playlist', json=week_data_input)

    torch_matching_tracks = next_week_top_tracks[next_week_top_tracks['id_track'].isin(torch_res.json())]
    xgb_matching_tracks = next_week_top_tracks[next_week_top_tracks['id_track'].isin(xgb_res.json())]

    return len(torch_matching_tracks), len(xgb_matching_tracks)

# %%
modelA_matches = []
modelB_matches = []
for week in weeks_to_test:
    modelA, modelB = get_matches_for_week(week)
    modelA_matches.append(modelA)
    modelB_matches.append(modelB)

# %%
modelA_matches, modelB_matches
# Out:
# ([23,
#   23,
#   24,
#   23,
#   24,
#   25,
#   22,
#   21,
#   27,
#   25,
#   24,
#   30,
#   24,
#   24,
#   28,
#   23,
#   26,
#   25,
#   23,
#   26],
#  [33,
#   30,
#   31,
#   26,
#   25,
#   28,
#   26,
#   30,
#   26,
#   24,
#   25,
#   31,
#   31,
#   27,
#   24,
#   27,
#   29,
#   28,
#   28,
#   28])

# %%
t_stat, p_val = stats.ttest_ind(modelA_matches, modelB_matches)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -4.511207179584193
# P-value: 6.0323872941076986e-05

# %%
p_val < 0.05
# Out:
# True

# %%
np.mean(modelA_matches), np.mean(modelB_matches)
# Out:
# (24.5, 27.85)

# %% [markdown]
# Based on low p-value, we can reject the null hypothesis and accept the alternative hypothesis - model B (XGBoost) is better than model A (Neural Network).

# %% [markdown]
# Neither of the models achived the analytical success criteria of 80% match between real top tracks and the generated playlis.
